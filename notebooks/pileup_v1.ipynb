# %%
import ROOT as RT
import numpy as np
from ROOT import TLatex
RT.enableJSVis()
# Out:
# Welcome to JupyROOT 6.12/07

# %%
import PyFunctions
from PyFunctions import *
# Out:
# /cvmfs/cms.cern.ch/slc6_amd64_gcc700/lcg/root/6.12.07-gnimlf5/lib/ROOT.py:434: UserWarning: "from ROOT import *" is not supported under IPython
#   warnings.warn( '"from ROOT import *" is not supported under IPython' )

# %%
proof = RT.TProof.Open("lite://", "workers=12")
# Out:
#  +++ Starting PROOF-Lite with 12 workers +++
# PROOF set to parallel mode (12 workers)
# /bin/rm: cannot remove '/uscms/home/hroutray/.proof/uscms_data-d3-hroutray-Jupyter-CMSSW_10_2_5-src-selections/session-cmslpc148.fnal.gov-1604522255-23997': Directory not empty
# Opening connections to workers: OK (12 workers)
# Setting up worker servers: OK (12 workers)

# %%
tree_mudata = RT.TChain('events')
tree_mudata.Add("~/nobackup/Jupyter/flatdimuontree_2017and2018_10percent_nosel.root")

tree_mubphi1 = RT.TChain('events')
tree_mubphi1.Add("~/nobackup/Jupyter/flat_dimuon_tree_BPhi_m0p5_ct1_flattree_vf.root")
tree_mubphi2 = RT.TChain('events')
tree_mubphi2.Add("~/nobackup/Jupyter/flat_dimuon_tree_BPhi_m2_ct10_flattree_vf.root")
tree_mubphi3 = RT.TChain('events')
tree_mubphi3.Add("~/nobackup/Jupyter/flat_dimuon_tree_BPhi_m4_ct100_flattree_vf.root")

tree_muhzd1 = RT.TChain('events')
tree_muhzd1.Add("~/nobackup/Jupyter/flat_dimuon_tree_HZdZd_m2_ct100_flattree_vf.root")
tree_muhzd2 = RT.TChain('events')
tree_muhzd2.Add("~/nobackup/Jupyter/flat_dimuon_tree_HZdZd_m8_ct10_flattree_vf.root")
tree_muhzd3 = RT.TChain('events')
tree_muhzd3.Add("~/nobackup/Jupyter/flat_dimuon_tree_HZdZd_m15_ct1_flattree_vf.root")
# Out:
# 1

# %%
tree_muproofdata = RT.TProofChain(tree_mudata, True)

tree_muproofbphi1 = RT.TProofChain(tree_mubphi1, True)
tree_muproofbphi2 = RT.TProofChain(tree_mubphi2, True)
tree_muproofbphi3 = RT.TProofChain(tree_mubphi3, True)

tree_muproofhzd1 = RT.TProofChain(tree_muhzd1, True)
tree_muproofhzd2 = RT.TProofChain(tree_muhzd2, True)
tree_muproofhzd3 = RT.TProofChain(tree_muhzd3, True)

# %%
tree_mudata.Print()
# Out:
# ******************************************************************************
# *Chain   :events    : ~/nobackup/Jupyter/flatdimuontree_2017and2018_10percent_nosel.root *
# ******************************************************************************
# ******************************************************************************
# *Tree    :events    : flat tree with dimuon info-L1HLTobjsel                 *
# *Entries : 214669705 : Total =     54246234771 bytes  File  Size = 34530171586 *
# *        :          : Tree compression factor =   1.57                       *
# ******************************************************************************
# *Br    0 :run       : run/F                                                  *
# *Entries :214669705 : Total  Size=  860886197 bytes  File Size  =    6851072 *
# *Baskets :    23990 : Basket Size=    2300416 bytes  Compression= 125.59     *
# *............................................................................*
# ...

# %%
c1=RT.TCanvas('c1','c1',600,600)

h0 = RT.TH1F("h0","",20,-5,5)
h1 = RT.TH1F("h1","",20,-5,5)

h01 = RT.TH1F("h01","",20,-5,5)
h11 = RT.TH1F("h11","",20,-5,5)

h02 = RT.TH1F("h02","",20,-5,5)
h12 = RT.TH1F("h12","",20,-5,5)

h03 = RT.TH1F("h03","",20,-5,5)
h13 = RT.TH1F("h13","",20,-5,5)

h04 = RT.TH1F("h04","",20,-5,5)
h14 = RT.TH1F("h14","",20,-5,5)

h05 = RT.TH1F("h05","",20,-5,5)
h15 = RT.TH1F("h15","",20,-5,5)


h1b = RT.TH1F("h1b","",20,-5,5)
h2b = RT.TH1F("h2b","",20,-5,5)
h3b = RT.TH1F("h3b","",20,-5,5)

h1zd = RT.TH1F("h1zd","",20,-5,5)
h2zd = RT.TH1F("h2zd","",20,-5,5)
h3zd = RT.TH1F("h3zd","",20,-5,5)

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h0','dimuon_mass < 5 && lxy > 0 && lxy < 0.2 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h1','dimuon_mass > 5 && lxy > 0 && lxy < 0.2 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h01','dimuon_mass < 5 && lxy > 0.2 && lxy < 1.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h11','dimuon_mass > 5 && lxy > 0.2 && lxy < 1.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h02','dimuon_mass < 5 && lxy > 1.0 && lxy < 2.4 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h12','dimuon_mass > 5 && lxy > 1.0 && lxy < 2.4 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h03','dimuon_mass < 5 && lxy > 2.4 && lxy < 3.1 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h13','dimuon_mass > 5 && lxy > 2.4 && lxy < 3.1 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h04','dimuon_mass < 5 && lxy > 3.1 && lxy < 7.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h14','dimuon_mass > 5 && lxy > 3.1 && lxy < 7.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h05','dimuon_mass < 5 && lxy > 7.0 && lxy < 11.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h15','dimuon_mass > 5 && lxy > 7.0 && lxy < 11.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4','')

tree_muproofbphi1.Draw('log10(abs(detamumu/dphimumu))>>h1b','','')
tree_muproofbphi2.Draw('log10(abs(detamumu/dphimumu))>>h2b','','')
tree_muproofbphi3.Draw('log10(abs(detamumu/dphimumu))>>h3b','','')

tree_muproofhzd1.Draw('log10(abs(detamumu/dphimumu))>>h1zd','','')
tree_muproofhzd2.Draw('log10(abs(detamumu/dphimumu))>>h2zd','','')
tree_muproofhzd3.Draw('log10(abs(detamumu/dphimumu))>>h3zd','','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h01.Scale(1/h01.Integral())
h11.Scale(1/h11.Integral())

h02.Scale(1/h02.Integral())
h12.Scale(1/h12.Integral())

h03.Scale(1/h03.Integral())
h13.Scale(1/h13.Integral())

h04.Scale(1/h04.Integral())
h14.Scale(1/h14.Integral())

h05.Scale(1/h05.Integral())
h15.Scale(1/h15.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)



h0.GetYaxis().SetRangeUser(0,1)
h0.GetXaxis().SetRangeUser(-5,5)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("log(abs(#Delta #eta(#mu,#mu)/#Delta #Phi(#mu,#mu)))")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)



GoodPlotFormat(h0, "thickline", 17, 20)
GoodPlotFormat(h1, "thickline", 23, 20)

GoodPlotFormat(h01, "thickline", 16, 20)
GoodPlotFormat(h11, "thickline", 24, 20)

GoodPlotFormat(h02, "thickline", 15, 20)
GoodPlotFormat(h12, "thickline", 25, 20)

GoodPlotFormat(h03, "thickline", 14, 20)
GoodPlotFormat(h13, "thickline", 26, 20)

GoodPlotFormat(h04, "thickline", 12, 20)
GoodPlotFormat(h14, "thickline", 27, 20)

GoodPlotFormat(h05, "thickline", 1, 20)
GoodPlotFormat(h15, "thickline", 28, 20)


GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

# h01.Draw("E1 SAME")
# h11.Draw("E1 SAME")

h02.Draw("E1 SAME")
h12.Draw("E1 SAME")

# h03.Draw("E1 SAME")
# h13.Draw("E1 SAME")

h04.Draw("E1 SAME")
h14.Draw("E1 SAME")

# h05.Draw("E1 SAME")
# h15.Draw("E1 SAME")


h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.1, 0.6, 0.6)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV) && 0.0 < lxy < 0.2", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV) && 0.0 < lxy < 0.2", "lpe") 

legend.AddEntry(h01 , "Data(< 5 GeV) && 0.2 < lxy < 1.0", "lpe")                                                                                                           
legend.AddEntry(h11, "Data(> 5 GeV) && 0.2 < lxy < 1.0", "lpe") 

legend.AddEntry(h02 , "Data(< 5 GeV) && 1.0 < lxy < 2.4", "lpe")                                                                                                           
legend.AddEntry(h12, "Data(> 5 GeV) && 1.0 < lxy < 2.4", "lpe") 

legend.AddEntry(h03 , "Data(< 5 GeV) && 2.4 < lxy < 3.1", "lpe")                                                                                                           
legend.AddEntry(h13, "Data(> 5 GeV) && 2.4 < lxy < 3.1", "lpe") 

legend.AddEntry(h04 , "Data(< 5 GeV) && 3.1 < lxy < 7.0", "lpe")                                                                                                           
legend.AddEntry(h14, "Data(> 5 GeV) && 3.1 < lxy < 7.0", "lpe") 

legend.AddEntry(h05 , "Data(< 5 GeV) && 7.0 < lxy < 11.0", "lpe")                                                                                                           
legend.AddEntry(h15, "Data(> 5 GeV) && 7.0 < lxy < 11.0", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm) && 0.0 < lxy < 11.0", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm) && 0.0 < lxy < 11.0", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm) && 0.0 < lxy < 11.0", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm) && 0.0 < lxy < 11.0", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm) && 0.0 < lxy < 11.0", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm) && 0.0 < lxy < 11.0", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 1.1, "Preliminary" )
c1.Draw()

l=RT.TLine(0.0,c1.GetUymin(),0.0,c1.GetUymax())
l.SetLineColor(2)
l.SetLineWidth(2)
l.SetLineStyle(2)
l.Draw()
a = RT.TArrow(0.0,3*c1.GetUymax()/4.0,-1.0,3*c1.GetUymax()/4.0)
a.SetLineColor(2)
a.Draw()


t = RT.TText(0.45,0.93,"")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
#c1.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h01 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h11 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h02 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h12 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h03 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h13 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h04 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h14 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h05 (Potential memory leak).
# ...

# %%
c1=RT.TCanvas('c1','c1',800,600)

h0 = RT.TH1F("h0","",20,-5,5)
h1 = RT.TH1F("h1","",20,-5,5)

h1b = RT.TH1F("h1b","",20,-5,5)
h2b = RT.TH1F("h2b","",20,-5,5)
h3b = RT.TH1F("h3b","",20,-5,5)

h1zd = RT.TH1F("h1zd","",20,-5,5)
h2zd = RT.TH1F("h2zd","",20,-5,5)
h3zd = RT.TH1F("h3zd","",20,-5,5)

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h0','dimuon_mass < 5 && lxy > 0 && lxy < 0.2 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h1','dimuon_mass > 5 && lxy > 0 && lxy < 0.2 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')

tree_muproofbphi1.Draw('log10(abs(detamumu/dphimumu))>>h1b','lxy > 0 && lxy < 0.2 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofbphi2.Draw('log10(abs(detamumu/dphimumu))>>h2b','lxy > 0 && lxy < 0.2 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofbphi3.Draw('log10(abs(detamumu/dphimumu))>>h3b','lxy > 0 && lxy < 0.2 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')

tree_muproofhzd1.Draw('log10(abs(detamumu/dphimumu))>>h1zd','lxy > 0 && lxy < 0.2 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofhzd2.Draw('log10(abs(detamumu/dphimumu))>>h2zd','lxy > 0 && lxy < 0.2 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofhzd3.Draw('log10(abs(detamumu/dphimumu))>>h3zd','lxy > 0 && lxy < 0.2 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)




h0.GetYaxis().SetRangeUser(0,0.5)
h0.GetXaxis().SetRangeUser(-5,5)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("log(abs(#Delta #eta(#mu,#mu)/#Delta #Phi(#mu,#mu)))")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)



GoodPlotFormat(h0, "markers", RT.kBlack, 20)
GoodPlotFormat(h1, "markers", RT.kBlue, 20)

GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.4, 0.5, 0.8)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV)", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV)", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm)", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm)", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm)", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm)", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 10.1, "#font[12]{Preliminary}" )
c1.Draw()

l=RT.TLine(1.25,c1.GetUymin(),1.25,c1.GetUymax())
l.SetLineColor(2)
l.SetLineWidth(2)
l.SetLineStyle(2)
l.Draw()
a = RT.TArrow(1.25,3*c1.GetUymax()/4.0,-1.0,3*c1.GetUymax()/4.0)
a.SetLineColor(2)
a.Draw()


t = RT.TText(0.45,0.93,"0.0 cm < lxy < 0.2 cm")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
#c1.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3zd (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 25
# ...

# %%
c1=RT.TCanvas('c1','c1',800,600)

h0 = RT.TH1F("h0","",20,-5,5)
h1 = RT.TH1F("h1","",20,-5,5)

h1b = RT.TH1F("h1b","",20,-5,5)
h2b = RT.TH1F("h2b","",20,-5,5)
h3b = RT.TH1F("h3b","",20,-5,5)

h1zd = RT.TH1F("h1zd","",20,-5,5)
h2zd = RT.TH1F("h2zd","",20,-5,5)
h3zd = RT.TH1F("h3zd","",20,-5,5)

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h0','dimuon_mass < 5 && lxy > 0.2 && lxy < 1.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h1','dimuon_mass > 5 && lxy > 0.2 && lxy < 1.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')

tree_muproofbphi1.Draw('log10(abs(detamumu/dphimumu))>>h1b','lxy > 0.2 && lxy < 1.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofbphi2.Draw('log10(abs(detamumu/dphimumu))>>h2b','lxy > 0.2 && lxy < 1.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofbphi3.Draw('log10(abs(detamumu/dphimumu))>>h3b','lxy > 0.2 && lxy < 1.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')

tree_muproofhzd1.Draw('log10(abs(detamumu/dphimumu))>>h1zd','lxy > 0.2 && lxy < 1.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofhzd2.Draw('log10(abs(detamumu/dphimumu))>>h2zd','lxy > 0.2 && lxy < 1.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofhzd3.Draw('log10(abs(detamumu/dphimumu))>>h3zd','lxy > 0.2 && lxy < 1.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)




h0.GetYaxis().SetRangeUser(0,0.5)
h0.GetXaxis().SetRangeUser(-5,5)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("log(abs(#Delta #eta(#mu,#mu)/#Delta #Phi(#mu,#mu)))")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)



GoodPlotFormat(h0, "markers", RT.kBlack, 20)
GoodPlotFormat(h1, "markers", RT.kBlue, 20)

GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.4, 0.5, 0.8)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV)", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV)", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm)", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm)", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm)", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm)", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 10.1, "#font[12]{Preliminary}" )
c1.Draw()

l=RT.TLine(1.25,c1.GetUymin(),1.25,c1.GetUymax())
l.SetLineColor(2)
l.SetLineWidth(2)
l.SetLineStyle(2)
l.Draw()
a = RT.TArrow(1.25,3*c1.GetUymax()/4.0,-1.0,3*c1.GetUymax()/4.0)
a.SetLineColor(2)
a.Draw()


t = RT.TText(0.45,0.93,"0.2 cm < lxy < 1.0 cm")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
#c1.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3zd (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 33
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# ...

# %%
c1=RT.TCanvas('c1','c1',800,600)

h0 = RT.TH1F("h0","",20,-5,5)
h1 = RT.TH1F("h1","",20,-5,5)

h1b = RT.TH1F("h1b","",20,-5,5)
h2b = RT.TH1F("h2b","",20,-5,5)
h3b = RT.TH1F("h3b","",20,-5,5)

h1zd = RT.TH1F("h1zd","",20,-5,5)
h2zd = RT.TH1F("h2zd","",20,-5,5)
h3zd = RT.TH1F("h3zd","",20,-5,5)

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h0','dimuon_mass < 5 && lxy > 1.0 && lxy < 11.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h1','dimuon_mass > 5 && lxy > 1.0 && lxy < 11.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')

tree_muproofbphi1.Draw('log10(abs(detamumu/dphimumu))>>h1b','lxy > 1.0 && lxy < 11.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofbphi2.Draw('log10(abs(detamumu/dphimumu))>>h2b','lxy > 1.0 && lxy < 11.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofbphi3.Draw('log10(abs(detamumu/dphimumu))>>h3b','lxy > 1.0 && lxy < 11.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')

tree_muproofhzd1.Draw('log10(abs(detamumu/dphimumu))>>h1zd','lxy > 1.0 && lxy < 11.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofhzd2.Draw('log10(abs(detamumu/dphimumu))>>h2zd','lxy > 1.0 && lxy < 11.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')
tree_muproofhzd3.Draw('log10(abs(detamumu/dphimumu))>>h3zd','lxy > 1.0 && lxy < 11.0 && muon1_ntrklayers > 5 && muon2_ntrklayers > 5 && muon1_chi2overndof < 3 && muon2_chi2overndof < 3 && abs(dphidimudv) < 0.02 && abs(dphimumu) < 2.4 && muon1_excesspixelhits <=0 && muon2_excesspixelhits <= 0','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)




h0.GetYaxis().SetRangeUser(0,0.5)
h0.GetXaxis().SetRangeUser(-5,5)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("log(abs(#Delta #eta(#mu,#mu)/#Delta #Phi(#mu,#mu)))")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)



GoodPlotFormat(h0, "markers", RT.kBlack, 20)
GoodPlotFormat(h1, "markers", RT.kBlue, 20)

GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.4, 0.5, 0.8)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV)", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV)", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm)", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm)", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm)", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm)", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 10.1, "#font[12]{Preliminary}" )
c1.Draw()

l=RT.TLine(1.25,c1.GetUymin(),1.25,c1.GetUymax())
l.SetLineColor(2)
l.SetLineWidth(2)
l.SetLineStyle(2)
l.Draw()
a = RT.TArrow(1.25,3*c1.GetUymax()/4.0,-1.0,3*c1.GetUymax()/4.0)
a.SetLineColor(2)
a.Draw()


t = RT.TText(0.45,0.93,"1.0 cm < lxy < 11.0 cm")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
#c1.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3zd (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 41
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# ...

# %%
c1=RT.TCanvas('c1','c1',600,600)

h0 = RT.TH1F("h0","",20,-5,5)
h1 = RT.TH1F("h1","",20,-5,5)

h1b = RT.TH1F("h1b","",20,-5,5)
h2b = RT.TH1F("h2b","",20,-5,5)
h3b = RT.TH1F("h3b","",20,-5,5)

h1zd = RT.TH1F("h1zd","",20,-5,5)
h2zd = RT.TH1F("h2zd","",20,-5,5)
h3zd = RT.TH1F("h3zd","",20,-5,5)

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h0','dimuon_mass < 5 && lxy > 0.2 && lxy < 1.0','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h1','dimuon_mass > 5 && lxy > 0.2 && lxy < 1.0','')

tree_muproofbphi1.Draw('log10(abs(detamumu/dphimumu))>>h1b','lxy > 0.2 && lxy < 1.0','')
tree_muproofbphi2.Draw('log10(abs(detamumu/dphimumu))>>h2b','lxy > 0.2 && lxy < 1.0','')
tree_muproofbphi3.Draw('log10(abs(detamumu/dphimumu))>>h3b','lxy > 0.2 && lxy < 1.0','')

tree_muproofhzd1.Draw('log10(abs(detamumu/dphimumu))>>h1zd','lxy > 0.2 && lxy < 1.0','')
tree_muproofhzd2.Draw('log10(abs(detamumu/dphimumu))>>h2zd','lxy > 0.2 && lxy < 1.0','')
tree_muproofhzd3.Draw('log10(abs(detamumu/dphimumu))>>h3zd','lxy > 0.2 && lxy < 1.0','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)




h0.GetYaxis().SetRangeUser(0,0.5)
h0.GetXaxis().SetRangeUser(-5,5)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("log(abs(#Delta #eta(#mu,#mu)/#Delta #Phi(#mu,#mu)))")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)



GoodPlotFormat(h0, "markers", RT.kBlack, 20)
GoodPlotFormat(h1, "markers", RT.kBlue, 20)

GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.1, 0.6, 0.6)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV)", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV)", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm)", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm)", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm)", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm)", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 1.1, "Preliminary" )
c1.Draw()

l=RT.TLine(1.25,c1.GetUymin(),1.25,c1.GetUymax())
l.SetLineColor(2)
l.SetLineWidth(2)
l.SetLineStyle(2)
l.Draw()
a = RT.TArrow(1.25,3*c1.GetUymax()/4.0,-1.0,3*c1.GetUymax()/4.0)
a.SetLineColor(2)
a.Draw()


t = RT.TText(0.45,0.93,"0.2 cm < lxy < 1.0 cm")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
#c1.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3zd (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 9
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# ...

# %%
c1=RT.TCanvas('c1','c1',600,600)

h0 = RT.TH1F("h0","",20,-5,5)
h1 = RT.TH1F("h1","",20,-5,5)

h1b = RT.TH1F("h1b","",20,-5,5)
h2b = RT.TH1F("h2b","",20,-5,5)
h3b = RT.TH1F("h3b","",20,-5,5)

h1zd = RT.TH1F("h1zd","",20,-5,5)
h2zd = RT.TH1F("h2zd","",20,-5,5)
h3zd = RT.TH1F("h3zd","",20,-5,5)

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h0','dimuon_mass < 5 && lxy > 1.0 && lxy < 2.4','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h1','dimuon_mass > 5 && lxy > 1.0 && lxy < 2.4','')

tree_muproofbphi1.Draw('log10(abs(detamumu/dphimumu))>>h1b','lxy > 1.0 && lxy < 2.4','')
tree_muproofbphi2.Draw('log10(abs(detamumu/dphimumu))>>h2b','lxy > 1.0 && lxy < 2.4','')
tree_muproofbphi3.Draw('log10(abs(detamumu/dphimumu))>>h3b','lxy > 1.0 && lxy < 2.4','')

tree_muproofhzd1.Draw('log10(abs(detamumu/dphimumu))>>h1zd','lxy > 1.0 && lxy < 2.4','')
tree_muproofhzd2.Draw('log10(abs(detamumu/dphimumu))>>h2zd','lxy > 1.0 && lxy < 2.4','')
tree_muproofhzd3.Draw('log10(abs(detamumu/dphimumu))>>h3zd','lxy > 1.0 && lxy < 2.4','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)




h0.GetYaxis().SetRangeUser(0,0.5)
h0.GetXaxis().SetRangeUser(-5,5)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("log(abs(#Delta #eta(#mu,#mu)/#Delta #Phi(#mu,#mu)))")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)



GoodPlotFormat(h0, "markers", RT.kBlack, 20)
GoodPlotFormat(h1, "markers", RT.kBlue, 20)

GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.1, 0.6, 0.6)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV)", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV)", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm)", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm)", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm)", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm)", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 1.1, "Preliminary" )
c1.Draw()

l=RT.TLine(1.25,c1.GetUymin(),1.25,c1.GetUymax())
l.SetLineColor(2)
l.SetLineWidth(2)
l.SetLineStyle(2)
l.Draw()
a = RT.TArrow(1.25,3*c1.GetUymax()/4.0,-1.0,3*c1.GetUymax()/4.0)
a.SetLineColor(2)
a.Draw()


t = RT.TText(0.45,0.93,"1.0 cm < lxy < 2.4 cm")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
#c1.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3zd (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 25
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# ...

# %%
c1=RT.TCanvas('c1','c1',600,600)

h0 = RT.TH1F("h0","",20,-5,5)
h1 = RT.TH1F("h1","",20,-5,5)

h1b = RT.TH1F("h1b","",20,-5,5)
h2b = RT.TH1F("h2b","",20,-5,5)
h3b = RT.TH1F("h3b","",20,-5,5)

h1zd = RT.TH1F("h1zd","",20,-5,5)
h2zd = RT.TH1F("h2zd","",20,-5,5)
h3zd = RT.TH1F("h3zd","",20,-5,5)

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h0','dimuon_mass < 5 && lxy > 2.4 && lxy < 3.1','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h1','dimuon_mass > 5 && lxy > 2.4 && lxy < 3.1','')

tree_muproofbphi1.Draw('log10(abs(detamumu/dphimumu))>>h1b','lxy > 2.4 && lxy < 3.1','')
tree_muproofbphi2.Draw('log10(abs(detamumu/dphimumu))>>h2b','lxy > 2.4 && lxy < 3.1','')
tree_muproofbphi3.Draw('log10(abs(detamumu/dphimumu))>>h3b','lxy > 2.4 && lxy < 3.1','')

tree_muproofhzd1.Draw('log10(abs(detamumu/dphimumu))>>h1zd','lxy > 2.4 && lxy < 3.1','')
tree_muproofhzd2.Draw('log10(abs(detamumu/dphimumu))>>h2zd','lxy > 2.4 && lxy < 3.1','')
tree_muproofhzd3.Draw('log10(abs(detamumu/dphimumu))>>h3zd','lxy > 2.4 && lxy < 3.1','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)




h0.GetYaxis().SetRangeUser(0,0.5)
h0.GetXaxis().SetRangeUser(-5,5)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("log(abs(#Delta #eta(#mu,#mu)/#Delta #Phi(#mu,#mu)))")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)



GoodPlotFormat(h0, "markers", RT.kBlack, 20)
GoodPlotFormat(h1, "markers", RT.kBlue, 20)

GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.1, 0.6, 0.6)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV)", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV)", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm)", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm)", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm)", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm)", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 1.1, "Preliminary" )
c1.Draw()

l=RT.TLine(1.25,c1.GetUymin(),1.25,c1.GetUymax())
l.SetLineColor(2)
l.SetLineWidth(2)
l.SetLineStyle(2)
l.Draw()
a = RT.TArrow(1.25,3*c1.GetUymax()/4.0,-1.0,3*c1.GetUymax()/4.0)
a.SetLineColor(2)
a.Draw()


t = RT.TText(0.45,0.93,"1.0 cm < lxy < 2.4 cm")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
#c1.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3zd (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 33
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# ...

# %%
c1=RT.TCanvas('c1','c1',600,600)

h0 = RT.TH1F("h0","",20,-5,5)
h1 = RT.TH1F("h1","",20,-5,5)

h1b = RT.TH1F("h1b","",20,-5,5)
h2b = RT.TH1F("h2b","",20,-5,5)
h3b = RT.TH1F("h3b","",20,-5,5)

h1zd = RT.TH1F("h1zd","",20,-5,5)
h2zd = RT.TH1F("h2zd","",20,-5,5)
h3zd = RT.TH1F("h3zd","",20,-5,5)

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h0','dimuon_mass < 5 && lxy > 3.1 && lxy < 7.0','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h1','dimuon_mass > 5 && lxy > 3.1 && lxy < 7.0','')

tree_muproofbphi1.Draw('log10(abs(detamumu/dphimumu))>>h1b','lxy > 3.1 && lxy < 7.0','')
tree_muproofbphi2.Draw('log10(abs(detamumu/dphimumu))>>h2b','lxy > 3.1 && lxy < 7.0','')
tree_muproofbphi3.Draw('log10(abs(detamumu/dphimumu))>>h3b','lxy > 3.1 && lxy < 7.0','')

tree_muproofhzd1.Draw('log10(abs(detamumu/dphimumu))>>h1zd','lxy > 3.1 && lxy < 7.0','')
tree_muproofhzd2.Draw('log10(abs(detamumu/dphimumu))>>h2zd','lxy > 3.1 && lxy < 7.0','')
tree_muproofhzd3.Draw('log10(abs(detamumu/dphimumu))>>h3zd','lxy > 3.1 && lxy < 7.0','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)




h0.GetYaxis().SetRangeUser(0,0.5)
h0.GetXaxis().SetRangeUser(-5,5)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("log(abs(#Delta #eta(#mu,#mu)/#Delta #Phi(#mu,#mu)))")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)



GoodPlotFormat(h0, "markers", RT.kBlack, 20)
GoodPlotFormat(h1, "markers", RT.kBlue, 20)

GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.1, 0.6, 0.6)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV)", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV)", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm)", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm)", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm)", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm)", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 1.1, "Preliminary" )
c1.Draw()

l=RT.TLine(1.25,c1.GetUymin(),1.25,c1.GetUymax())
l.SetLineColor(2)
l.SetLineWidth(2)
l.SetLineStyle(2)
l.Draw()
a = RT.TArrow(0.0,3*c1.GetUymax()/4.0,-1.0,3*c1.GetUymax()/4.0)
a.SetLineColor(2)
a.Draw()


t = RT.TText(0.45,0.93,"3.1 cm < lxy < 7.0 cm")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
#c1.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3zd (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 17
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# ...

# %%
c1=RT.TCanvas('c1','c1',600,600)

h0 = RT.TH1F("h0","",20,-5,5)
h1 = RT.TH1F("h1","",20,-5,5)

h1b = RT.TH1F("h1b","",20,-5,5)
h2b = RT.TH1F("h2b","",20,-5,5)
h3b = RT.TH1F("h3b","",20,-5,5)

h1zd = RT.TH1F("h1zd","",20,-5,5)
h2zd = RT.TH1F("h2zd","",20,-5,5)
h3zd = RT.TH1F("h3zd","",20,-5,5)

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h0','dimuon_mass < 5 && lxy > 7.0 && lxy < 11.0','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h1','dimuon_mass > 5 && lxy > 7.0 && lxy < 11.0','')

tree_muproofbphi1.Draw('log10(abs(detamumu/dphimumu))>>h1b','lxy > 7.0 && lxy < 11.0','')
tree_muproofbphi2.Draw('log10(abs(detamumu/dphimumu))>>h2b','lxy > 7.0 && lxy < 11.0','')
tree_muproofbphi3.Draw('log10(abs(detamumu/dphimumu))>>h3b','lxy > 7.0 && lxy < 11.0','')

tree_muproofhzd1.Draw('log10(abs(detamumu/dphimumu))>>h1zd','lxy > 7.0 && lxy < 11.0','')
tree_muproofhzd2.Draw('log10(abs(detamumu/dphimumu))>>h2zd','lxy > 7.0 && lxy < 11.0','')
tree_muproofhzd3.Draw('log10(abs(detamumu/dphimumu))>>h3zd','lxy > 7.0 && lxy < 11.0','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)




h0.GetYaxis().SetRangeUser(0,0.8)
h0.GetXaxis().SetRangeUser(-5,5)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("Trailing Muon n(Valid-Expected) Hits")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)



GoodPlotFormat(h0, "markers", RT.kBlack, 20)
GoodPlotFormat(h1, "markers", RT.kBlue, 20)

GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.1, 0.6, 0.6)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV)", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV)", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm)", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm)", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm)", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm)", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 1.1, "Preliminary" )
c1.Draw()

l=RT.TLine(1.25,c1.GetUymin(),1.25,c1.GetUymax())
l.SetLineColor(2)
l.SetLineWidth(2)
l.SetLineStyle(2)
l.Draw()
a = RT.TArrow(0.0,3*c1.GetUymax()/4.0,-1.0,3*c1.GetUymax()/4.0)
a.SetLineColor(2)
a.Draw()


t = RT.TText(0.45,0.93,"7.0 cm < lxy < 11.0 cm")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
#c1.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3zd (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 65
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# ...

# %%
c1=RT.TCanvas('c1','c1',600,600)

h0 = RT.TH1F("h0","",40,-5,5)
h1 = RT.TH1F("h1","",40,-5,5)

h1b = RT.TH1F("h1b","",40,-5,5)
h2b = RT.TH1F("h2b","",40,-5,5)
h3b = RT.TH1F("h3b","",40,-5,5)

h1zd = RT.TH1F("h1zd","",40,-5,5)
h2zd = RT.TH1F("h2zd","",40,-5,5)
h3zd = RT.TH1F("h3zd","",40,-5,5)

tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h0','dimuon_mass < 5 && lxy > 1.0 && lxy < 11.0','')
tree_muproofdata.Draw('log10(abs(detamumu/dphimumu))>>h1','dimuon_mass > 5 && lxy > 1.0 && lxy < 11.0','')

tree_muproofbphi1.Draw('log10(abs(detamumu/dphimumu))>>h1b','lxy > 1.0 && lxy < 11.0','')
tree_muproofbphi2.Draw('log10(abs(detamumu/dphimumu))>>h2b','lxy > 1.0 && lxy < 11.0','')
tree_muproofbphi3.Draw('log10(abs(detamumu/dphimumu))>>h3b','lxy > 1.0 && lxy < 11.0','')

tree_muproofhzd1.Draw('log10(abs(detamumu/dphimumu))>>h1zd','lxy > 1.0 && lxy < 11.0','')
tree_muproofhzd2.Draw('log10(abs(detamumu/dphimumu))>>h2zd','lxy > 1.0 && lxy < 11.0','')
tree_muproofhzd3.Draw('log10(abs(detamumu/dphimumu))>>h3zd','lxy > 1.0 && lxy < 11.0','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)




h0.GetYaxis().SetRangeUser(0,0.3)
h0.GetXaxis().SetRangeUser(-3,4)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("log(abs(#Delta #eta(#mu,#mu)/#Delta #Phi(#mu,#mu)))")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)



GoodPlotFormat(h0, "markers", RT.kBlack, 20)
GoodPlotFormat(h1, "markers", RT.kBlue, 20)

GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.1, 0.6, 0.6)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV)", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV)", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm)", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm)", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm)", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm)", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 1.1, "Preliminary" )
c1.Draw()

l=RT.TLine(1.25,c1.GetUymin(),1.25,c1.GetUymax())
l.SetLineColor(2)
l.SetLineWidth(2)
l.SetLineStyle(2)
l.Draw()
a = RT.TArrow(1.25,3*c1.GetUymax()/4.0,-1.0,3*c1.GetUymax()/4.0)
a.SetLineColor(2)
a.Draw()


t = RT.TText(0.45,0.93,"1.0 cm < lxy < 11.0 cm")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
#c1.SetLogy()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3zd (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 105
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# ...
