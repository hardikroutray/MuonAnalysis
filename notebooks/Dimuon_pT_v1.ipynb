# %%
import ROOT as RT
import numpy as np
from ROOT import TLatex
RT.enableJSVis()
# Out:
# Welcome to JupyROOT 6.12/07

# %%
import PyFunctions
from PyFunctions import *
# Out:
# /cvmfs/cms.cern.ch/slc6_amd64_gcc700/lcg/root/6.12.07-gnimlf5/lib/ROOT.py:434: UserWarning: "from ROOT import *" is not supported under IPython
#   warnings.warn( '"from ROOT import *" is not supported under IPython' )

# %%
proof = RT.TProof.Open("lite://", "workers=12")
# Out:
#  +++ Starting PROOF-Lite with 12 workers +++
# PROOF set to parallel mode (12 workers)
# /bin/rm: cannot remove '/uscms/home/hroutray/.proof/uscms_data-d3-hroutray-Jupyter-CMSSW_10_2_5-src-selections/session-cmslpc124.fnal.gov-1600713268-12964/.nfs000000008d15d8650000000e': Device or resource busy
# Opening connections to workers: OK (12 workers)
# Setting up worker servers: OK (12 workers)

# %%
tree_mudata = RT.TChain('t')
tree_mudata.Add("~/nobackup/Jupyter/data_subset_pass_all.root")

tree_mubphi1 = RT.TChain('events')
tree_mubphi1.Add("~/nobackup/Jupyter/flat_dimuon_tree_BPhi_m0p5_ct1_flattree_vf.root")
tree_mubphi2 = RT.TChain('events')
tree_mubphi2.Add("~/nobackup/Jupyter/flat_dimuon_tree_BPhi_m2_ct10_flattree_vf.root")
tree_mubphi3 = RT.TChain('events')
tree_mubphi3.Add("~/nobackup/Jupyter/flat_dimuon_tree_BPhi_m4_ct100_flattree_vf.root")

tree_muhzd1 = RT.TChain('events')
tree_muhzd1.Add("~/nobackup/Jupyter/flat_dimuon_tree_HZdZd_m2_ct100_flattree_vf.root")
tree_muhzd2 = RT.TChain('events')
tree_muhzd2.Add("~/nobackup/Jupyter/flat_dimuon_tree_HZdZd_m8_ct10_flattree_vf.root")
tree_muhzd3 = RT.TChain('events')
tree_muhzd3.Add("~/nobackup/Jupyter/flat_dimuon_tree_HZdZd_m15_ct1_flattree_vf.root")
# Out:
# 1

# %%
tree_muproofdata = RT.TProofChain(tree_mudata, True)

tree_muproofbphi1 = RT.TProofChain(tree_mubphi1, True)
tree_muproofbphi2 = RT.TProofChain(tree_mubphi2, True)
tree_muproofbphi3 = RT.TProofChain(tree_mubphi3, True)

tree_muproofhzd1 = RT.TProofChain(tree_muhzd1, True)
tree_muproofhzd2 = RT.TProofChain(tree_muhzd2, True)
tree_muproofhzd3 = RT.TProofChain(tree_muhzd3, True)

# %%
tree_mudata.Print()
# Out:
# ******************************************************************************
# *Chain   :t         : ~/nobackup/Jupyter/data_subset_pass_all.root           *
# ******************************************************************************
# ******************************************************************************
# *Tree    :t         :                                                        *
# *Entries :  6453564 : Total =        25822021 bytes  File  Size =     120528 *
# *        :          : Tree compression factor = 253.27                       *
# ******************************************************************************
# *Br    0 :dimuon_pt : dimuon_pt/F                                            *
# *Entries :  6453564 : Total  Size=   25815268 bytes  File Size  =   25814767 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    1 :mass      : mass/F                                                 *
# *Entries :  6453564 : Total  Size=   25815213 bytes  File Size  =   25814732 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    2 :pass_all  : pass_all/O                                             *
# *Entries :  6453564 : Total  Size=    6454559 bytes  File Size  =      26004 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression= 248.20     *
# *............................................................................*
# *Br    3 :DV_x      : DV_x/F                                                 *
# *Entries :  6453564 : Total  Size=   25815213 bytes  File Size  =   25814732 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    4 :DV_y      : DV_y/F                                                 *
# *Entries :  6453564 : Total  Size=   25815213 bytes  File Size  =   25814732 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    5 :DV_z      : DV_z/F                                                 *
# *Entries :  6453564 : Total  Size=   25815213 bytes  File Size  =   25814732 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    6 :DV_xError : DV_xError/F                                            *
# *Entries :  6453564 : Total  Size=   25815268 bytes  File Size  =   25814767 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    7 :DV_yError : DV_yError/F                                            *
# *Entries :  6453564 : Total  Size=   25815268 bytes  File Size  =   25814767 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    8 :DV_zError : DV_zError/F                                            *
# *Entries :  6453564 : Total  Size=   25815268 bytes  File Size  =   25814767 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    9 :lxy       : lxy/F                                                  *
# *Entries :  6453564 : Total  Size=   25815202 bytes  File Size  =   25814725 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   10 :run       : run/I                                                  *
# *Entries :  6453564 : Total  Size=   25815202 bytes  File Size  =     102972 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression= 250.70     *
# *............................................................................*
# *Br   11 :event     : event/L                                                *
# *Entries :  6453564 : Total  Size=   51629488 bytes  File Size  =   33856137 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.52     *
# *............................................................................*
# *Br   12 :luminosityBlock : luminosityBlock/I                                *
# *Entries :  6453564 : Total  Size=   25815334 bytes  File Size  =     279086 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=  92.50     *
# *............................................................................*
# *Br   13 :year      : year/I                                                 *
# *Entries :  6453564 : Total  Size=   25815213 bytes  File Size  =     101927 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression= 253.27     *
# *............................................................................*

# %%
c1=RT.TCanvas('c1','c1',600,600)

h0 = RT.TH1F("h0","",100,0,100)
h1 = RT.TH1F("h1","",100,0,100)

h1b = RT.TH1F("h1b","",100,0,100)
h2b = RT.TH1F("h2b","",100,0,100)
h3b = RT.TH1F("h3b","",100,0,100)

h1zd = RT.TH1F("h1zd","",100,0,100)
h2zd = RT.TH1F("h2zd","",100,0,100)
h3zd = RT.TH1F("h3zd","",100,0,100)

tree_muproofdata.Draw('dimuon_pt>>h0','mass < 5','')
tree_muproofdata.Draw('dimuon_pt>>h1','mass > 5','')

tree_muproofbphi1.Draw('dimuon_pt>>h1b','','')
tree_muproofbphi2.Draw('dimuon_pt>>h2b','','')
tree_muproofbphi3.Draw('dimuon_pt>>h3b','','')

tree_muproofhzd1.Draw('dimuon_pt>>h1zd','','')
tree_muproofhzd2.Draw('dimuon_pt>>h2zd','','')
tree_muproofhzd3.Draw('dimuon_pt>>h3zd','','')

h0.Scale(1/h0.Integral())
h1.Scale(1/h1.Integral())

h1b.Scale(1/h1b.Integral())
h2b.Scale(1/h2b.Integral())
h3b.Scale(1/h3b.Integral())

h1zd.Scale(1/h1zd.Integral())
h2zd.Scale(1/h2zd.Integral())
h3zd.Scale(1/h3zd.Integral())

# h0.SetLineColor(1)
# h1.SetLineColor(4)

# h1b.SetLineColor(91)
# h2b.SetLineColor(94)
# h3b.SetLineColor(98)

# h1zd.SetLineColor(71)
# h2zd.SetLineColor(61)
# h3zd.SetLineColor(51)




# h0.SetTitle("0 cm < lxy < 11 cm")
# RT.gStyle.SetTitleX(0.3)
# RT.gStyle.SetTitleY(0.9)
# RT.gStyle.SetTitleW(0.3)
# #RT.gStyle.SetTitleH(0.2)
# RT.gStyle.SetTitleTextColor(8)




# h1b.GetYaxis().SetRangeUser(0,0.15)
# h1b.GetXaxis().SetRangeUser(0,100)
# h1b.GetYaxis().SetTitle("Fraction of Events")
# h1b.GetXaxis().SetTitle("Dimuon pT(in GeV)")
# h1b.GetYaxis().SetTitleOffset(1.5)
# RT.gStyle.SetLabelColor(1)

h0.GetYaxis().SetRangeUser(0,0.15)
h0.GetXaxis().SetRangeUser(0,100)
h0.GetYaxis().SetTitle("Fraction of Events")
h0.GetXaxis().SetTitle("Dimuon pT(in GeV)")
h0.GetYaxis().SetTitleOffset(1.5)
RT.gStyle.SetLabelColor(1)


GoodPlotFormat(h0, "markers", RT.kBlack, 20)
GoodPlotFormat(h1, "markers", RT.kBlue, 20)

GoodPlotFormat(h1b, "thickline", 91, 2)
GoodPlotFormat(h2b, "thickline", 94, 2)
GoodPlotFormat(h3b, "thickline", 98, 2)

GoodPlotFormat(h1zd, "thickline", 71, 2)
GoodPlotFormat(h2zd, "thickline", 65, 2)
GoodPlotFormat(h3zd, "thickline", 51, 2)


h0.Draw("E1")
h1.Draw("E1 SAME")

h1b.Draw("HIST SAME")
h2b.Draw("HIST SAME")
h3b.Draw("HIST SAME")

h1zd.Draw("HIST SAME")
h2zd.Draw("HIST SAME")
h3zd.Draw("HIST SAME")


legend = RT.TLegend(0.1, 0.1, 0.6, 0.6)  
legend.SetBorderSize(0)                                                                                                                                                              
legend.SetFillColorAlpha(0,0)                                                                                                                                                               
legend.SetTextSize(0.03) 
# legend.SetHeader("0 cm < lxy < 11 cm")
legend.AddEntry(h0 , "Data(< 5 GeV)", "lpe")                                                                                                           
legend.AddEntry(h1, "Data(> 5 GeV)", "lpe") 

legend.AddEntry(h1b , "B->Phi(mass = 0.5 GeV, ctau = 1 mm)", "F")
legend.AddEntry(h2b , "B->Phi(mass = 2 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3b , "B->Phi(mass = 4 GeV, ctau = 100 mm)", "F")                                                                                                           

legend.AddEntry(h1zd , "H->ZdZd(mass = 2 GeV, ctau = 100 mm)", "F")
legend.AddEntry(h2zd , "H->ZdZd(mass = 8 GeV, ctau = 10 mm)", "F")                                                                                                           
legend.AddEntry(h3zd , "H->ZdZd(mass = 15 GeV, ctau = 1 mm)", "F")                                                                                                           

legend.SetTextFont(22)
legend.Draw()


AddCMSLumi(c1, 10.1, "#font[12]{Preliminary}" )
c1.Draw()

l=RT.TLine(25.0,c1.GetUymin(),25.0,c1.GetUymax())
l.SetLineColor(1)
l.Draw()
# a = RT.TArrow(3.0,3.9*c1.GetUymax()/4.0,1.0,3.9*c1.GetUymax()/4.0)
# a.SetLineColor(2)
# a.Draw()


t = RT.TText(0.45,0.93,"0.0 cm < lxy < 11.0 cm")
t.SetTextAlign(22)
t.SetTextColor(8)
t.SetTextFont(42)
t.SetTextSize(20)
t.SetTextAngle(0)
t.SetNDC(1)
t.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3b (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h1zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h2zd (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h3zd (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 9
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# Info in <TPacketizer::TPacketizer>: Initial number of workers: 12
# [TProof::Progress] Total 6453564 events	|====================| 100.00 % [22253668.0 evts/s, 2.0 GB/s, time left: 0.0 s]
#  Query processing time: 0.3 s
# Info in <TProofDrawHist::SetDrawAtt>: att: 1000
# Lite-0: all output objects have been merged
# Info in <TProofLite::SetQueryRunning>: starting query: 10
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# Info in <TPacketizer::TPacketizer>: Initial number of workers: 12
# [TProof::Progress] Total 6453564 events	|====================| 100.00 % [26022436.0 evts/s, 2.3 GB/s, time left: 0.0 s]
#  Query processing time: 0.2 s
# Info in <TProofDrawHist::SetDrawAtt>: att: 1000
# Lite-0: all output objects have been merged
# Info in <TProofLite::SetQueryRunning>: starting query: 11
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# Info in <TPacketizer::TPacketizer>: Initial number of workers: 12
# [TProof::Progress] Total 4305 events	|====================| 100.00 % [538125.1 evts/s, 33.6 MB/s, time left: 0.0 s]
#  Query processing time: 0.0 s
# Info in <TProofDrawHist::SetDrawAtt>: att: 1000
# Lite-0: all output objects have been merged
# Info in <TProofLite::SetQueryRunning>: starting query: 12
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# Info in <TPacketizer::TPacketizer>: Initial number of workers: 12
# [TProof::Progress] Total 3422 events	|====================| 100.00 % [427750.0 evts/s, 29.2 MB/s, time left: 0.0 s]
#  Query processing time: 0.0 s
# Info in <TProofDrawHist::SetDrawAtt>: att: 1000
# Lite-0: all output objects have been merged
# Info in <TProofLite::SetQueryRunning>: starting query: 13
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# Info in <TPacketizer::TPacketizer>: Initial number of workers: 12
# [TProof::Progress] Total 1563 events	|====================| 100.00 % [173666.7 evts/s, 17.8 MB/s, time left: 0.0 s]
#  Query processing time: 0.0 s
# Info in <TProofDrawHist::SetDrawAtt>: att: 1000
# Lite-0: all output objects have been merged
# Info in <TProofLite::SetQueryRunning>: starting query: 14
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# Info in <TPacketizer::TPacketizer>: Initial number of workers: 12
# [TProof::Progress] Total 4155 events	|====================| 100.00 % [415500.0 evts/s, 26.5 MB/s, time left: 0.0 s]
#  Query processing time: 0.0 s
# Info in <TProofDrawHist::SetDrawAtt>: att: 1000
# Lite-0: all output objects have been merged
# Info in <TProofLite::SetQueryRunning>: starting query: 15
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# Info in <TPacketizer::TPacketizer>: Initial number of workers: 12
# [TProof::Progress] Total 7070 events	|====================| 100.00 % [785555.6 evts/s, 42.1 MB/s, time left: 0.0 s]
#  Query processing time: 0.0 s
# Info in <TProofDrawHist::SetDrawAtt>: att: 1000
# Lite-0: all output objects have been merged
# Info in <TProofLite::SetQueryRunning>: starting query: 16
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# Info in <TPacketizer::TPacketizer>: Initial number of workers: 12
# [TProof::Progress] Total 12526 events	|====================| 100.00 % [1391777.9 evts/s, 67.2 MB/s, time left: 0.0 s]
#  Query processing time: 0.0 s
# Info in <TProofDrawHist::SetDrawAtt>: att: 1000
# Lite-0: all output objects have been merged
# <div id="root_plot_2"
#      style="width: 596px; height: 572px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-12.5000009313226,"fY1":-0.0187500013969839,"fX2":112.500000931323,"fY2":0.168750001396984,"fXtoAbsPixelk":59.600053552437,"fXtoPixelk":59.600053552437,"fXtoPixel":4.76799992895126,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-3050.66662120819,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":596,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-12.5000009313226,"fPixeltoXk":-12.5000009313226,"fPixeltoX":0.209731546749405,"fAbsPixeltoYk":0.168750001396984,"fPixeltoYk":-0.0187500013969839,"fPixeltoY":-3.27797207681762e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":100,"fUymax":0.15,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":true,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":100,"fY2":0.15,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50332168,"fName":"h0","fTitle":"","fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":20,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50333704,"fName":"xaxis","fTitle":"Dimuon pT(in GeV)","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.04,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":0,"fXmax":100,"fXbins":[],"fFirst":1,"fLast":100,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331656,"fName":"yaxis","fTitle":"Fraction of Events","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1.5,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":6443527,"fTsumw":6443367,"fTsumw2":6443367,"fTsumwx":96002095.7698975,"fTsumwx2":1727459533.90399,"fMaximum":0.15,"fMinimum":0,"fNormFactor":0,"fContour":[],"fSumw2":[0,0,0,0,0,2.16778782301643e-13,1.00464922331128e-10,1.84777416727647e-9,6.32683328066166e-9,1.09240368304013e-8,1.39741865569795e-8,1.50621510922887e-8,1.4620163241707e-8,1.33181898752033e-8,1.16993341020374e-8,1.00835132318237e-8,8.62639851678613e-9,7.30937106817818e-9,6.16875337530103e-9,5.2238628363109e-9,4.40612509640637e-9,3.73167813160322e-9,3.14526743894591e-9,2.65286647821341e-9,2.25091044276343e-9,1.91540914735459e-9,1.63371716301929e-9,1.39133439787468e-9,1.1823355 ...
