# %%
import ROOT as RT
import numpy as np
from ROOT import TLatex
RT.enableJSVis()
# Out:
# Welcome to JupyROOT 6.12/07

# %%
import PyFunctions
from PyFunctions import *
# Out:
# /cvmfs/cms.cern.ch/slc6_amd64_gcc700/lcg/root/6.12.07-gnimlf5/lib/ROOT.py:434: UserWarning: "from ROOT import *" is not supported under IPython
#   warnings.warn( '"from ROOT import *" is not supported under IPython' )

# %%
proof = RT.TProof.Open("lite://", "workers=12")
# Out:
#  +++ Starting PROOF-Lite with 12 workers +++
# PROOF set to parallel mode (12 workers)
# Opening connections to workers: OK (12 workers)
# Setting up worker servers: OK (12 workers)

# %%
tree_mudata = RT.TChain('events')
tree_mudata.Add("~/nobackup/Jupyter/flatdimuontree_17_10percent_final.root")
# Out:
# 1

# %%
tree_mudata.Print()
# Out:
# ******************************************************************************
# *Chain   :events    : ~/nobackup/Jupyter/flatdimuontree_17_10percent_final.root *
# ******************************************************************************
# ******************************************************************************
# *Tree    :events    : flat tree with dimuon info                             *
# *Entries : 165604421 : Total =      7309096300 bytes  File  Size = 6737871353 *
# *        :          : Tree compression factor =   1.08                       *
# ******************************************************************************
# *Br    0 :dimuon_pt : dimuon_pt/F                                            *
# *Entries :165604421 : Total  Size=  664486295 bytes  File Size  =  584880959 *
# *Baskets :    21105 : Basket Size=      32000 bytes  Compression=   1.14     *
# *............................................................................*
# *Br    1 :dimuon_mass : dimuon_mass/F                                        *
# *Entries :165604421 : Total  Size=  664528713 bytes  File Size  =  596409194 *
# *Baskets :    21107 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br    2 :Lxy       : Lxy/F                                                  *
# *Entries :165604421 : Total  Size=  664359549 bytes  File Size  =  627580227 *
# *Baskets :    21104 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br    3 :lxymod    : lxymod/F                                               *
# *Entries :165604421 : Total  Size=  664422873 bytes  File Size  =  627643573 *
# *Baskets :    21104 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br    4 :ctau      : ctau/F                                                 *
# *Entries :165604421 : Total  Size=  664380657 bytes  File Size  =  626247133 *
# *Baskets :    21104 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br    5 :muon1_eta : muon1_eta/F                                            *
# *Entries :165604421 : Total  Size=  664486295 bytes  File Size  =  609360194 *
# *Baskets :    21105 : Basket Size=      32000 bytes  Compression=   1.09     *
# *............................................................................*
# *Br    6 :muon2_eta : muon2_eta/F                                            *
# *Entries :165604421 : Total  Size=  664486295 bytes  File Size  =  606232021 *
# *Baskets :    21105 : Basket Size=      32000 bytes  Compression=   1.10     *
# *............................................................................*
# *Br    7 :muon1_phi : muon1_phi/F                                            *
# *Entries :165604421 : Total  Size=  664486295 bytes  File Size  =  613802294 *
# *Baskets :    21105 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br    8 :muon2_phi : muon2_phi/F                                            *
# *Entries :165604421 : Total  Size=  664486295 bytes  File Size  =  613802560 *
# *Baskets :    21105 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br    9 :delta_eta : delta_eta/F                                            *
# *Entries :165604421 : Total  Size=  664486295 bytes  File Size  =  613133424 *
# *Baskets :    21105 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br   10 :delta_phi : delta_phi/F                                            *
# *Entries :165604421 : Total  Size=  664486295 bytes  File Size  =  616306578 *
# *Baskets :    21105 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*

# %%
tree_muproofdata = RT.TProofChain(tree_mudata, True)

# %%
c1=RT.TCanvas('c1','c1',600,600)

h0 = RT.TH2D("h0","",1000,-20,20,1000,-20,20)

tree_muproofdata.Draw('DVx:DVy>>h0','','')

h0.Draw("colz")
c1.Draw()
# Out:
#
# OBJ: TStatus	PROOF_Status	ERROR
#
#    Errors:
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
# 	TProofDrawHist::CompileVariables: Error compiling variables
#
#  Max worker virtual memory: 444.68 MB 	Max worker resident memory: 226.34 MB
#  Max master virtual memory: -0.00 MB 	Max master resident memory: -0.00 MB
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Warning in <TROOT::Append>: Replacing existing TH1: h0 (Potential memory leak).
# Info in <TProofLite::SetQueryRunning>: starting query: 10
# Info in <TProofQueryResult::SetRunning>: nwrks: 12
# Looking up for exact location of files: OK (1 files)
# Looking up for exact location of files: OK (1 files)
# Info in <TPacketizer::TPacketizer>: Initial number of workers: 12
# Validating files: OK (1 files)
# Info in <TProofDrawHist::SetDrawAtt>: att: 1000
# Lite-0: all output objects have been merged
# <div id="root_plot_10"
#      style="width: 596px; height: 572px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-25.0000003725291,"fY1":-25.0000003725291,"fX2":25.0000003725291,"fY2":25.0000003725291,"fXtoAbsPixelk":298.00005,"fXtoPixelk":298.00005,"fXtoPixel":11.9199998223782,"fYtoAbsPixelk":286.00005,"fYtoPixelk":286.00005,"fYtoPixel":-11.4399998295307,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":596,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-25.0000003725291,"fPixeltoXk":-25.0000003725291,"fPixeltoX":0.0838926186997619,"fAbsPixeltoYk":25.0000003725291,"fPixeltoYk":-25.0000003725291,"fPixeltoY":-0.0874125887151365,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-20,"fUymin":-20,"fUxmax":20,"fUymax":20,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-20,"fY1":-20,"fX2":20,"fY2":20,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH2D","fUniqueID":0,"fBits":50331656,"fName":"h0","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":1004004,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1000,"fXmin":-20,"fXmax":20,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1000,"fXmin":-20,"fXmax":20,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":0,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":14.000001013279,"fY1":9.75000053271653,"fX2":24.0000013113022,"fY2":21.7500004433096,"fX1NDC":0.780000016093254,"fY1NDC":0.695000007748604,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC","fName":"stats","fTextAngle":0,"fTextSize":0,"fTextAlign":12,"fTextColor":1,"fTextFont":42," ...
